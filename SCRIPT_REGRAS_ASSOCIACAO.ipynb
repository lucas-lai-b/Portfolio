# %%
#Título: Script Python para Análise de Cesta de Compras via Algoritmo de Regras de Associação
#Autor: Lucas Lai Barbosa

#Importação das bibliotecas necessárias
import pypyodbc as podbc
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore', '.*pandas only support SQLAlchemy.*', )

from mlxtend.frequent_patterns import fpgrowth, association_rules

# %%
#Conexão com o servidor
conn = podbc.connect("Driver={SQL Server};Server=192.168.99.63;Database=ODS;Trusted_Connection=yes")

# %%
#Ajuste de visualização do Jupyter Notebook
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 110)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
#Consulta SQL ao banco de dados para extração das informações das compras
SQL_Query = pd.read_sql_query('''WITH ITENS_1 AS (
	SELECT 
	--RIGHT(ID_LOJA, 4) AS 'ID_LOJA',
	CONCAT(DATA_COMPRA,'_' , ID_COMPRA) 'DATA_ID_COMPRA',
	CASE WHEN CONCAT(DEPARTAMENTO_PRODUTO, ' - ', SUBGRUPO_PRODUTO) = 'CINTO - HOMEM' THEN 'OUTROS ACESS - ACS CINTO MASCULINO' 
		 WHEN CONCAT(DEPARTAMENTO_PRODUTO, ' - ', SUBGRUPO_PRODUTO) IN ('MEIA - MULHER','MEIA - MEIA CALCA') THEN 'MEIA - ACS MEIA FEMININO'
		 ELSE CONCAT(DEPARTAMENTO_PRODUTO, ' - ', SUBGRUPO_PRODUTO) END 'DEP_SUBGRUPO',
	QUANTIDADE_PRODUTO
FROM
	CDP.TRANSACIONAL_VENDA
WHERE
	DATA_COMPRA BETWEEN '2022-03-01' AND '2022-05-31'
	AND OPERACAO_PRODUTO LIKE 'COMPRA%'
	AND SUBGRUPO_PRODUTO IS NOT NULL
	AND ORIGEM IN ('STOREX', 'PDV', 'WHATSAPP')

),
ITENS_2 AS (
SELECT 
	DATA_ID_COMPRA,
	COUNT(DEP_SUBGRUPO) AS 'QTD'
FROM ITENS_1
GROUP BY DATA_ID_COMPRA
HAVING COUNT(DEP_SUBGRUPO) > 1
)

SELECT * FROM 
(
	SELECT 
	I.DATA_ID_COMPRA,
	I.DEP_SUBGRUPO,
	I.QUANTIDADE_PRODUTO
	FROM ITENS_1 I 
		INNER JOIN ITENS_2 I2 ON I.DATA_ID_COMPRA = I2.DATA_ID_COMPRA
) t
PIVOT (
	SUM(QUANTIDADE_PRODUTO)
	FOR DEP_SUBGRUPO IN ([FECHADO - FEM BOTA CANO MD/AL],[MENINA - INF MNA JUV SANDALIA],[FECHADO - FEM TNS C CADARCO],[MENINO - INF MNO RECEM NASCIDO],[FECHADO - FEM SPT ALTO],[MENINO - INF MNO PP TENIS],[ABERTO - FEM SND ALTA],[CASUAL - MASC BOTA CASUAL],[ACESS FEM - ACS CINTO FEMININO],[OUTROS ACESS - ACS CHAPEU INFANTIL],[MENINA - INF MNA JUV SAPATO],[CINTO - HOMEM],[FECHADO - FEM SPT RASTEIRO],[MASCULINO - TNS MASC TREINO],[FEMININO - TNS FEM MULTIESPORTES],[MENINO - INF MNO JUV BOTA],[CASUAL - MASC SPT CADARCO],[FEMININO - CHL FEMININO],[CHECKSTAND - ACS PAPELARIA],[ACESS FEM - ACS BOLSA FEMININO],[OUTROS ACESS - ACS CHAPEU ADULTO],[FECHADO - FEM SPT MEDIO],[SOCIAL - MASC SPT SOCIAL],[MENINO - INF MNO INF BOTA],[MENINO - INF MNO INF TENIS],[MENINA - INF MNA BB TENIS],[MEIA - ACS MEIA MASCULINO],[MENINA - INF MNA JUV BOTA],[CASUAL - MASC SPT S CADARCO],[OUTROS ACESS - ACS CINTO MASCULINO],[FECHADO - FEM TNS S CADARCO],[MEIA - MULHER],[ABERTO - FEM SND BAIXA],[CALCADO - ALTO],[CASUAL - MASC SAND CASUAL],[MENINA - INF MNA JUV TENIS],[OUTROS ACESS - ACS CARTEIRA MASCULINO],[ABERTO - FEM TCO MEDIO],[MENINO - INF MNO INF SANDALIA],[MENINA - INF MNA PP SAPATO],[MENINO - INF MNO BB SANDALIA],[MENINO - INF MNO BB SAPATO],[OUTROS ACESS - ACS BOLSA INFANTIL],[MENINO - INF MNO PP SANDALIA],[MENINO - INF MNO INF SAPATO],[ABERTO - FEM SND RASTEIRA],[INFANTIL - CHL MNO INF],[MENINA - INF MNA RECEM NASCIDO],[INFANTIL - CHL MNA INF],[OUTROS ACESS - ACS MOCHILA INFANTIL],[CALCADO - CASUAL],[ACESS FEM - ACS CARTEIRA FEMININO],[ABERTO - FEM TCO RASTEIRO],[CASUAL - MASC BOTA OUTDOOR],[OUTROS ACESS - ACS MOCHILA ADULTO],[FEMININO - TNS FEM CORRIDA],[MENINO - INF MNO PP SAPATO],[MENINA - INF MNA PP SANDALIA],[INFANTIL - CHL MNA PP],[MENINA - INF MNA INF BOTA],[MASCULINO - CHL MASC PRAIA],[ - ],[MENINO - INF MNO JUV SAPATO],[ABERTO - FEM TCO ALTO],[MENINA - INF MNA INF SAPATO],[CHECKSTAND - ACS ALMOFADA],[FECHADO - FEM BOTA CANO BX],[FECHADO - FEM SAPATILHA],[MENINA - INF MNA PP TENIS],[MENINA - INF MNA PP BOTA],[MENINA - INF MNA BB SAPATO],[MASCULINO - TNS MASC MULTIESPORTES],[MEIA - ACS MEIA MENINA],[MENINA - INF MNA INF SANDALIA],[MASCULINO - CHL MASC CASUAL],[FECHADO - FEM BOTA COTURNO],[MENINO - INF MNO JUV SANDALIA],[MEIA - MEIA CALCA],[CHECKSTAND - ACS BELEZA],[FECHADO - FEM SPT BAIXO],[MENINO - INF MNO BB TENIS],[CALCADO - MEDIO],[CHECKSTAND - ACS PRODUTO PE],[ABERTO - FEM TCO BAIXO],[CALCADO - CONFORT],[CHECKSTAND - ACS COPO],[MEIA - ACS MEIA FEMININO],[CALCADO - BAIXO],[INFANTIL - CHL MNO PP],[CASUAL - MASC TNS CASUAL],[CHECKSTAND - ACS NECESSAIRE],[MENINO - INF MNO JUV TENIS],[PERFUMARIA - ACS PERFUMARIA],[MENINO - INF MNO PP BOTA],[ABERTO - FEM SND MEDIA],[MEIA - ACS MEIA MENINO],[CHECKSTAND - ACS CHECKSTAND OUTROS],[FEMININO - TNS FEM TREINO],[OUTROS ACESS - ACS PANTUFA],[MENINA - INF MNA INF TENIS],[MASCULINO - TNS MASC CORRIDA],[MENINA - INF MNA BB SANDALIA],[CASUAL - MASC SAPATENIS])
	) AS PIVOT_TABLE
ORDER BY 1''', conn)
data = pd.DataFrame(SQL_Query)

# %%
data.head(5)
# Out:
#                                   data_id_compra  \
# 0  Apr  1 2022  1:00PM_20220401|1068|18|42303|59
# 1   Apr  1 2022  1:00PM_20220401|1076|6|23771|50
# 2   Apr  1 2022  1:00PM_20220401|1100|1|31534|11
# 3   Apr  1 2022  1:00PM_20220401|1123|3|37056|55
# 4    Apr  1 2022  1:00PM_20220401|1127|8|33480|9
#
#    fechado - fem bota cano md/al  menina - inf mna juv sandalia  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                           1.00
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    fechado - fem tns c cadarco  menino - inf mno recem nascido  \
# 0                          NaN                             NaN
# 1                         1.00                             NaN
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
#
#    fechado - fem spt alto  menino - inf mno pp tenis  aberto - fem snd alta  \
# 0                    1.00                        NaN                    NaN
# 1                     NaN                        NaN                    NaN
# 2                     NaN                        NaN                    NaN
# 3                     NaN                        NaN                    NaN
# 4                     NaN                        NaN                    NaN
#
#    casual - masc bota casual  acess fem - acs cinto feminino  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    outros acess - acs chapeu infantil  menina - inf mna juv sapato  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
#
#   cinto - homem  fechado - fem spt rasteiro  masculino - tns masc treino  \
# 0          None                         NaN                          NaN
# 1          None                         NaN                          NaN
# 2          None                         NaN                          NaN
# 3          None                         NaN                          NaN
# 4          None                         NaN                          NaN
#
#    feminino - tns fem multiesportes  menino - inf mno juv bota  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
#
#    casual - masc spt cadarco  feminino - chl feminino  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#    checkstand - acs papelaria  acess fem - acs bolsa feminino  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                             NaN
# 3                         NaN                             NaN
# 4                         NaN                             NaN
#
#    outros acess - acs chapeu adulto  fechado - fem spt medio  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
#
#    social - masc spt social  menino - inf mno inf bota  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#    menino - inf mno inf tenis  menina - inf mna bb tenis  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                        2.00                        NaN
#
#    meia - acs meia masculino  menina - inf mna juv bota  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                       1.00                        NaN
#
#    casual - masc spt s cadarco  outros acess - acs cinto masculino  \
# 0                          NaN                                 NaN
# 1                          NaN                                 NaN
# 2                          NaN                                 NaN
# 3                          NaN                                 NaN
# 4                          NaN                                 NaN
#
#    fechado - fem tns s cadarco meia - mulher  aberto - fem snd baixa  \
# 0                          NaN          None                     NaN
# 1                          NaN          None                     NaN
# 2                          NaN          None                     NaN
# 3                          NaN          None                     NaN
# 4                          NaN          None                     NaN
#
#    calcado - alto  casual - masc sand casual  menina - inf mna juv tenis  \
# 0             NaN                        NaN                         NaN
# 1             NaN                        NaN                         NaN
# 2             NaN                        NaN                         NaN
# 3             NaN                        NaN                         NaN
# 4             NaN                        NaN                         NaN
#
#    outros acess - acs carteira masculino  aberto - fem tco medio  \
# 0                                    NaN                     NaN
# 1                                    NaN                     NaN
# 2                                    NaN                     NaN
# 3                                    NaN                     NaN
# 4                                    NaN                     NaN
#
#    menino - inf mno inf sandalia  menina - inf mna pp sapato  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#    menino - inf mno bb sandalia  menino - inf mno bb sapato  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#    outros acess - acs bolsa infantil  menino - inf mno pp sandalia  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#    menino - inf mno inf sapato  aberto - fem snd rasteira  \
# 0                          NaN                       1.00
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
#
#    infantil - chl mno inf  menina - inf mna recem nascido  \
# 0                     NaN                             NaN
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
#
#    infantil - chl mna inf  outros acess - acs mochila infantil  \
# 0                     NaN                                  NaN
# 1                     NaN                                  NaN
# 2                     NaN                                  NaN
# 3                     NaN                                  NaN
# 4                     NaN                                  NaN
#
#    calcado - casual  acess fem - acs carteira feminino  \
# 0               NaN                                NaN
# 1               NaN                                NaN
# 2               NaN                                NaN
# 3               NaN                                NaN
# 4               NaN                                NaN
#
#    aberto - fem tco rasteiro  casual - masc bota outdoor  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    outros acess - acs mochila adulto  feminino - tns fem corrida  \
# 0                                NaN                         NaN
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                                NaN                         NaN
# 4                                NaN                         NaN
#
#    menino - inf mno pp sapato  menina - inf mna pp sandalia  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#    infantil - chl mna pp  menina - inf mna inf bota  \
# 0                    NaN                        NaN
# 1                    NaN                        NaN
# 2                    NaN                        NaN
# 3                    NaN                        NaN
# 4                    NaN                        NaN
#
#    masculino - chl masc praia    -   menino - inf mno juv sapato  \
# 0                         NaN  None                          NaN
# 1                         NaN  None                          NaN
# 2                         NaN  None                          NaN
# 3                         NaN  None                          NaN
# 4                         NaN  None                          NaN
#
#    aberto - fem tco alto  menina - inf mna inf sapato  \
# 0                    NaN                          NaN
# 1                    NaN                          NaN
# 2                    NaN                          NaN
# 3                    NaN                          NaN
# 4                    NaN                          NaN
#
#    checkstand - acs almofada  fechado - fem bota cano bx  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    fechado - fem sapatilha  menina - inf mna pp tenis  \
# 0                      NaN                        NaN
# 1                      NaN                        NaN
# 2                      NaN                        NaN
# 3                     2.00                        NaN
# 4                      NaN                        NaN
#
#    menina - inf mna pp bota  menina - inf mna bb sapato  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
#    masculino - tns masc multiesportes  meia - acs meia menina  \
# 0                                 NaN                     NaN
# 1                                 NaN                     NaN
# 2                                 NaN                     NaN
# 3                                 NaN                     NaN
# 4                                 NaN                     NaN
#
#    menina - inf mna inf sandalia  masculino - chl masc casual  \
# 0                            NaN                          NaN
# 1                            NaN                         1.00
# 2                           1.00                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#    fechado - fem bota coturno  menino - inf mno juv sandalia  \
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
#
#   meia - meia calca  checkstand - acs beleza  fechado - fem spt baixo  \
# 0              None                      NaN                      NaN
# 1              None                      NaN                      NaN
# 2              None                      NaN                      NaN
# 3              None                      NaN                      NaN
# 4              None                      NaN                      NaN
#
#    menino - inf mno bb tenis  calcado - medio  checkstand - acs produto pe  \
# 0                        NaN              NaN                          NaN
# 1                        NaN              NaN                          NaN
# 2                        NaN              NaN                          NaN
# 3                        NaN              NaN                          NaN
# 4                        NaN              NaN                          NaN
#
#    aberto - fem tco baixo  calcado - confort  checkstand - acs copo  \
# 0                     NaN                NaN                   1.00
# 1                     NaN                NaN                    NaN
# 2                     NaN                NaN                    NaN
# 3                     NaN                NaN                    NaN
# 4                     NaN                NaN                    NaN
#
#    meia - acs meia feminino  calcado - baixo  infantil - chl mno pp  \
# 0                       NaN              NaN                    NaN
# 1                       NaN              NaN                    NaN
# 2                       NaN              NaN                    NaN
# 3                       NaN              NaN                    NaN
# 4                       NaN              NaN                    NaN
#
#    casual - masc tns casual  checkstand - acs necessaire  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#    menino - inf mno juv tenis  perfumaria - acs perfumaria  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    menino - inf mno pp bota  aberto - fem snd media  meia - acs meia menino  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
#
#    checkstand - acs checkstand outros  feminino - tns fem treino  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
#
#    outros acess - acs pantufa  menina - inf mna inf tenis  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    masculino - tns masc corrida  menina - inf mna bb sandalia  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    casual - masc sapatenis
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                     1.00

# %%
data.shape
# Out:
# (788471, 104)

# %%
#Substituição dos número de peças vendidas por valores boolianos (0 ou 1)
data2 = data.fillna(0)
column_names = data2.select_dtypes(include=[np.number]).columns
data2[column_names] = data2[column_names].astype(bool)

data2.shape
# Out:
# (788471, 104)

# %%
#Descarte da coluna de identificação da compra
data2.drop(columns='data_id_compra', inplace=True)

# %%
#Geração das combinações de produtos mais comuns
frequent_itemsets = fpgrowth(data2, min_support=0.002, use_colnames=True)

print(frequent_itemsets.sort_values(by='support', ascending=False))
# Out:
#      support                                           itemsets
# 40      0.15                        (aberto - fem tco rasteiro)
# 8       0.11                        (meia - acs meia masculino)
# 3       0.10                      (fechado - fem tns c cadarco)
# 7       0.10                          (fechado - fem sapatilha)
# 32      0.10                         (meia - acs meia feminino)
# ..       ...                                                ...
# 211     0.00  (feminino - chl feminino, fechado - fem spt ra...
# 146     0.00  (feminino - chl feminino, feminino - tns fem t...
# 178     0.00  (fechado - fem spt medio, fechado - fem tns s ...
# 139     0.00  (fechado - fem sapatilha, fechado - fem bota c...
# 269     0.00   (infantil - chl mno inf, meia - acs meia menino)
#
# [270 rows x 2 columns]

# %%
#Cálculo dos indicadores das regras de associação mais frequentes
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
rules[ (rules['confidence'] >= 0.1) &
       (rules['lift'] >= 1)].sort_values(by='confidence', ascending=False)
# Out:
#                              antecedents  \
# 0            (aberto - fem snd rasteira)
# 39         (masculino - tns masc treino)
# 35              (aberto - fem tco baixo)
# 73           (casual - masc bota casual)
# 78            (social - masc spt social)
# 13              (aberto - fem tco medio)
# 53            (casual - masc tns casual)
# 77            (social - masc spt social)
# 11             (casual - masc sapatenis)
# 66   (acess fem - acs carteira feminino)
# 21           (feminino - tns fem treino)
# 69               (aberto - fem tco alto)
# 29              (meia - acs meia menina)
# 74              (aberto - fem snd baixa)
# 51  (outros acess - acs cinto masculino)
# 44          (fechado - fem spt rasteiro)
# 30           (menina - inf mna pp tenis)
# 43          (fechado - fem spt rasteiro)
# 34         (menina - inf mna inf sapato)
# 41             (feminino - chl feminino)
# 81              (meia - acs meia menino)
# 47            (meia - acs meia feminino)
# 45            (meia - acs meia feminino)
# 36             (fechado - fem spt medio)
# 70          (masculino - chl masc praia)
# 46         (fechado - fem tns c cadarco)
# 1            (aberto - fem tco rasteiro)
# 31              (meia - acs meia menina)
# 55         (casual - masc spt s cadarco)
# 9        (menina - inf mna inf sandalia)
# 6        (menina - inf mna inf sandalia)
# 80           (menino - inf mno pp tenis)
# 76  (outros acess - acs cinto masculino)
# 48           (meia - acs meia masculino)
# 84              (meia - acs meia menino)
# 25              (meia - acs meia menina)
# 19          (fechado - fem bota coturno)
# 82          (menino - inf mno inf tenis)
# 28          (menina - inf mna inf tenis)
# 24         (fechado - fem tns s cadarco)
# 22         (fechado - fem tns s cadarco)
# 20           (feminino - tns fem treino)
# 75              (aberto - fem snd baixa)
# 83              (meia - acs meia menino)
# 67              (infantil - chl mna inf)
# 27              (meia - acs meia menina)
# 62         (checkstand - acs produto pe)
# 40         (masculino - tns masc treino)
# 4          (masculino - chl masc casual)
# 57              (infantil - chl mno inf)
# 12              (aberto - fem tco medio)
# 23         (fechado - fem tns s cadarco)
# 16               (aberto - fem snd alta)
# 79              (meia - acs meia menino)
# 52            (casual - masc tns casual)
# 26              (meia - acs meia menina)
# 56         (casual - masc spt s cadarco)
# 61         (checkstand - acs produto pe)
# 32          (menina - inf mna inf tenis)
# 58          (menino - inf mno inf tenis)
# 49             (checkstand - acs beleza)
# 14              (aberto - fem snd media)
# 38           (meia - acs meia masculino)
# 65  (checkstand - acs checkstand outros)
# 60              (infantil - chl mno inf)
# 2            (aberto - fem snd rasteira)
# 33       (menina - inf mna inf sandalia)
# 54            (casual - masc tns casual)
# 7           (menina - inf mna inf tenis)
#
#                              consequents  antecedent support  \
# 0            (aberto - fem tco rasteiro)                0.08
# 39           (meia - acs meia masculino)                0.05
# 35           (aberto - fem tco rasteiro)                0.04
# 73           (meia - acs meia masculino)                0.01
# 78           (meia - acs meia masculino)                0.02
# 13           (aberto - fem tco rasteiro)                0.03
# 53           (meia - acs meia masculino)                0.04
# 77  (outros acess - acs cinto masculino)                0.02
# 11           (meia - acs meia masculino)                0.05
# 66      (acess fem - acs bolsa feminino)                0.01
# 21            (meia - acs meia feminino)                0.04
# 69           (aberto - fem tco rasteiro)                0.01
# 29          (menina - inf mna inf tenis)                0.02
# 74           (aberto - fem tco rasteiro)                0.02
# 51           (meia - acs meia masculino)                0.03
# 44           (aberto - fem tco rasteiro)                0.05
# 30              (meia - acs meia menina)                0.02
# 43             (fechado - fem sapatilha)                0.05
# 34       (menina - inf mna inf sandalia)                0.01
# 41           (aberto - fem tco rasteiro)                0.06
# 81          (menino - inf mno inf tenis)                0.02
# 47           (meia - acs meia masculino)                0.10
# 45         (fechado - fem tns c cadarco)                0.10
# 36             (fechado - fem sapatilha)                0.04
# 70             (feminino - chl feminino)                0.04
# 46            (meia - acs meia feminino)                0.10
# 1            (aberto - fem snd rasteira)                0.15
# 31           (menina - inf mna pp tenis)                0.02
# 55           (meia - acs meia masculino)                0.02
# 9               (infantil - chl mna inf)                0.02
# 6           (menina - inf mna inf tenis)                0.02
# 80              (meia - acs meia menino)                0.02
# 76            (social - masc spt social)                0.03
# 48            (meia - acs meia feminino)                0.11
# 84           (meia - acs meia masculino)                0.02
# 25            (meia - acs meia feminino)                0.02
# 19            (meia - acs meia feminino)                0.04
# 82              (meia - acs meia menino)                0.03
# 28              (meia - acs meia menina)                0.03
# 24         (fechado - fem tns c cadarco)                0.05
# 22            (meia - acs meia feminino)                0.05
# 20           (meia - acs meia masculino)                0.04
# 75           (aberto - fem snd rasteira)                0.02
# 83            (meia - acs meia feminino)                0.02
# 67             (feminino - chl feminino)                0.03
# 27           (meia - acs meia masculino)                0.02
# 62           (meia - acs meia masculino)                0.02
# 40            (meia - acs meia feminino)                0.05
# 4            (meia - acs meia masculino)                0.04
# 57          (menino - inf mno inf tenis)                0.03
# 12              (aberto - fem snd media)                0.03
# 23             (fechado - fem sapatilha)                0.05
# 16              (aberto - fem snd media)                0.05
# 79           (menino - inf mno pp tenis)                0.02
# 52             (casual - masc sapatenis)                0.04
# 26              (meia - acs meia menino)                0.02
# 56             (casual - masc sapatenis)                0.02
# 61            (meia - acs meia feminino)                0.02
# 32              (infantil - chl mna inf)                0.03
# 58              (infantil - chl mno inf)                0.03
# 49            (meia - acs meia feminino)                0.04
# 14           (aberto - fem snd rasteira)                0.05
# 38         (masculino - tns masc treino)                0.11
# 65            (meia - acs meia feminino)                0.03
# 60             (feminino - chl feminino)                0.03
# 2              (fechado - fem sapatilha)                0.08
# 33         (menina - inf mna inf sapato)                0.02
# 54            (meia - acs meia feminino)                0.04
# 7        (menina - inf mna inf sandalia)                0.03
#
#     consequent support  support  confidence  lift  leverage  conviction
# 0                 0.15     0.02        0.27  1.79      0.01        1.16
# 39                0.11     0.01        0.22  1.97      0.01        1.14
# 35                0.15     0.01        0.22  1.46      0.00        1.09
# 73                0.11     0.00        0.22  1.95      0.00        1.14
# 78                0.11     0.00        0.21  1.87      0.00        1.12
# 13                0.15     0.01        0.20  1.36      0.00        1.07
# 53                0.11     0.01        0.20  1.82      0.00        1.11
# 77                0.03     0.00        0.19  7.27      0.00        1.21
# 11                0.11     0.01        0.18  1.63      0.00        1.09
# 66                0.03     0.00        0.18  5.16      0.00        1.18
# 21                0.10     0.01        0.18  1.76      0.00        1.09
# 69                0.15     0.00        0.17  1.15      0.00        1.03
# 29                0.03     0.00        0.17  6.04      0.00        1.17
# 74                0.15     0.00        0.17  1.12      0.00        1.02
# 51                0.11     0.00        0.17  1.50      0.00        1.07
# 44                0.15     0.01        0.16  1.10      0.00        1.02
# 30                0.02     0.00        0.16  7.47      0.00        1.17
# 43                0.10     0.01        0.16  1.59      0.00        1.07
# 34                0.02     0.00        0.16  7.87      0.00        1.17
# 41                0.15     0.01        0.16  1.06      0.00        1.01
# 81                0.03     0.00        0.16  5.53      0.00        1.15
# 47                0.11     0.02        0.15  1.36      0.00        1.05
# 45                0.10     0.02        0.15  1.46      0.00        1.06
# 36                0.10     0.01        0.15  1.50      0.00        1.06
# 70                0.06     0.01        0.15  2.40      0.00        1.10
# 46                0.10     0.02        0.15  1.46      0.00        1.05
# 1                 0.08     0.02        0.14  1.79      0.01        1.07
# 31                0.02     0.00        0.14  7.47      0.00        1.14
# 55                0.11     0.00        0.14  1.25      0.00        1.03
# 9                 0.03     0.00        0.14  4.63      0.00        1.13
# 6                 0.03     0.00        0.14  4.97      0.00        1.13
# 80                0.02     0.00        0.14  5.82      0.00        1.13
# 76                0.02     0.00        0.14  7.27      0.00        1.14
# 48                0.10     0.02        0.14  1.36      0.00        1.04
# 84                0.11     0.00        0.13  1.21      0.00        1.03
# 25                0.10     0.00        0.13  1.34      0.00        1.04
# 19                0.10     0.01        0.13  1.34      0.00        1.04
# 82                0.02     0.00        0.13  5.53      0.00        1.12
# 28                0.02     0.00        0.13  6.04      0.00        1.13
# 24                0.10     0.01        0.13  1.26      0.00        1.03
# 22                0.10     0.01        0.13  1.28      0.00        1.03
# 20                0.11     0.01        0.12  1.12      0.00        1.01
# 75                0.08     0.00        0.12  1.55      0.00        1.05
# 83                0.10     0.00        0.12  1.22      0.00        1.02
# 67                0.06     0.00        0.12  1.91      0.00        1.06
# 27                0.11     0.00        0.12  1.05      0.00        1.01
# 62                0.11     0.00        0.12  1.05      0.00        1.01
# 40                0.10     0.01        0.12  1.16      0.00        1.02
# 4                 0.11     0.00        0.12  1.03      0.00        1.00
# 57                0.03     0.00        0.11  4.02      0.00        1.10
# 12                0.05     0.00        0.11  2.06      0.00        1.07
# 23                0.10     0.01        0.11  1.11      0.00        1.01
# 16                0.05     0.01        0.11  2.01      0.00        1.06
# 79                0.02     0.00        0.11  5.82      0.00        1.10
# 52                0.05     0.00        0.11  2.31      0.00        1.07
# 26                0.02     0.00        0.11  4.55      0.00        1.09
# 56                0.05     0.00        0.11  2.29      0.00        1.07
# 61                0.10     0.00        0.11  1.07      0.00        1.01
# 32                0.03     0.00        0.11  3.56      0.00        1.09
# 58                0.03     0.00        0.11  4.02      0.00        1.09
# 49                0.10     0.00        0.11  1.06      0.00        1.01
# 14                0.08     0.01        0.11  1.32      0.00        1.03
# 38                0.05     0.01        0.10  1.97      0.01        1.06
# 65                0.10     0.00        0.10  1.03      0.00        1.00
# 60                0.06     0.00        0.10  1.65      0.00        1.05
# 2                 0.10     0.01        0.10  1.01      0.00        1.00
# 33                0.01     0.00        0.10  7.87      0.00        1.10
# 54                0.10     0.00        0.10  1.01      0.00        1.00
# 7                 0.02     0.00        0.10  4.97      0.00        1.09

# %% [markdown]
# 𝑠𝑢𝑝 (𝐴) = 𝑛ú𝑚𝑒𝑟𝑜 𝑑𝑒 𝑡𝑟𝑎𝑛𝑠𝑎çõ𝑒𝑠 𝑐𝑜𝑚 𝐴 / 𝑛ú𝑚𝑒𝑟𝑜 𝑡𝑜𝑡𝑎𝑙 𝑑𝑒 𝑡𝑟𝑎𝑛𝑠𝑎çõ𝑒𝑠
#
# 𝑠𝑢𝑝 (𝐴 → 𝐵) = 𝑛ú𝑚𝑒𝑟𝑜 𝑑𝑒 𝑡𝑟𝑎𝑛𝑠𝑎çõ𝑒𝑠 𝑐𝑜𝑚 𝐴 𝑒 𝐵 / 𝑛ú𝑚𝑒𝑟𝑜 𝑡𝑜𝑡𝑎𝑙 𝑑𝑒 𝑡𝑟𝑎𝑛𝑠𝑎çõ𝑒𝑠
#
# 𝑐𝑜𝑛𝑓 (𝐴 → 𝐵) = 𝑛ú𝑚𝑒𝑟𝑜 𝑑𝑒 𝑡𝑟𝑎𝑛𝑠𝑎çõ𝑒𝑠 𝑞𝑢𝑒 𝑠𝑢𝑝𝑜𝑟𝑡𝑎𝑚 (𝐴 ∪ 𝐵) / 𝑛ú𝑚𝑒𝑟𝑜 𝑑𝑒 𝑡𝑟𝑎𝑛𝑠𝑎çõ𝑒𝑠 𝑞𝑢𝑒 𝑠𝑢𝑝𝑜𝑟𝑡𝑎𝑚 A
#
# 𝑙𝑖𝑓𝑡 (𝐴 → 𝐵) = 𝑠𝑢𝑝(𝐴 → 𝐵) / ( 𝑠𝑢𝑝 𝐴 × 𝑠𝑢𝑝(𝐵) )

# %%
#Exportação dos resultados para planilha do Excel
rules.to_excel("Regras.xlsx")
